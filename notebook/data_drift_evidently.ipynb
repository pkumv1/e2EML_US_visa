# %%
import numpy as np
import pandas as pd
from evidently.dashboard import Dashboard

# from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from evidently.dashboard import Dashboard
#       5 # from evidently.dashboard import Dashboard
#       6 from evidently.tabs import DataDriftTab, CatTargetDriftTab
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\dashboard\__init__.py:6
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
#       4 import warnings
# ----> 6 from .dashboard import Dashboard
#       8 warnings.warn("dashboards are deprecated, use metrics instead")
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\dashboard\dashboard.py:17
#      13 from typing import Tuple
#      15 import pandas
# ---> 17 from evidently.dashboard.tabs.base_tab import Tab
#      18 from evidently.model.dashboard import DashboardInfo
#      19 from evidently.model.widget import AdditionalGraphInfo
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\dashboard\tabs\__init__.py:4
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
# ----> 4 from .cat_target_drift_tab import CatTargetDriftTab
#       5 from .classification_performance_tab import ClassificationPerformanceTab
#       6 from .data_drift_tab import DataDriftTab
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\dashboard\tabs\cat_target_drift_tab.py:3
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
# ----> 3 from evidently.dashboard.tabs.base_tab import Tab
#       4 from evidently.dashboard.tabs.base_tab import Verbose
#       5 from evidently.dashboard.widgets.cat_output_drift_widget import CatOutputDriftWidget
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\dashboard\tabs\base_tab.py:12
#       8 from typing import Union
#      10 import pandas
# ---> 12 from evidently.analyzers.base_analyzer import Analyzer
#      13 from evidently.dashboard.widgets.widget import Widget
#      14 from evidently.model.widget import BaseWidgetInfo
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\analyzers\base_analyzer.py:9
#       5 from typing import Optional
#       7 import pandas as pd
# ----> 9 from evidently.metric_results import DatasetColumns
#      10 from evidently.options import OptionsProvider
#      11 from evidently.pipeline.column_mapping import ColumnMapping
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\metric_results.py:10
#       7 import numpy as np
#       8 import pandas as pd
# ---> 10 from evidently.base_metric import MetricResult
#      11 from evidently.base_metric import MetricResultField
#      12 from evidently.pipeline.column_mapping import TargetNames
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\base_metric.py:22
#      19 from pydantic import BaseConfig
#      20 from pydantic import BaseModel
# ---> 22 from evidently.features.generated_features import GeneratedFeature
#      23 from evidently.pipeline.column_mapping import ColumnMapping
#      24 from evidently.utils.data_preprocessing import DataDefinition
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\features\generated_features.py:7
#       3 from typing import Optional
#       5 import pandas as pd
# ----> 7 from evidently.utils.data_preprocessing import DataDefinition
#      10 class GeneratedFeature:
#      11     """
#      12     Class for computation of additional features.
#      13     """
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\utils\__init__.py:1
# ----> 1 from .numpy_encoder import NumpyEncoder
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\evidently\utils\numpy_encoder.py:26
#       5 import pandas as pd
#       7 from evidently.utils.types import ApproxValue
#       9 _TYPES_MAPPING = (
#      10     (
#      11         (
#      12             np.int_,
#      13             np.intc,
#      14             np.intp,
#      15             np.int8,
#      16             np.int16,
#      17             np.int32,
#      18             np.int64,
#      19             np.uint8,
#      20             np.uint16,
#      21             np.uint32,
#      22             np.uint64,
#      23         ),
#      24         int,
#      25     ),
# ---> 26     ((np.float_, np.float16, np.float32, np.float64), float),
#      27     ((np.ndarray,), lambda obj: obj.tolist()),
#      28     ((np.bool_), bool),
#      29     ((pd.Timedelta,), str),
#      30     (
#      31         (np.void, type(pd.NaT)),
#      32         lambda obj: None,
#      33     ),  # should be before datetime as NaT is subclass of datetime.
#      34     ((pd.Timestamp, datetime.datetime, datetime.date), lambda obj: obj.isoformat()),
#      35     # map ApproxValue to json value
#      36     ((ApproxValue,), lambda obj: obj.as_dict()),
#      37 )
#      40 class NumpyEncoder(json.JSONEncoder):
#      41     """Numpy and Pandas data types to JSON types encoder"""
#
# File c:\Users\Admin\anaconda3\envs\usvisa\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     raise AttributeError(__former_attrs__[attr], name=None)
#     413 if attr in __expired_attributes__:
# --> 414     raise AttributeError(
#     415         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     416         f"{__expired_attributes__[attr]}",
#     417         name=None
#     418     )
#     420 if attr == "chararray":
#     421     warnings.warn(
#     422         "`np.chararray` is deprecated and will be removed from "
#     423         "the main namespace in the future. Use an array with a string "
#     424         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.

# %% [markdown]
# # Load Boston Data Set

# %%
data_url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
boston_frame = pd.read_csv(data_url)

# %%
boston_frame.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston_frame.shape
# Out:
# (506, 14)

# %%
boston_frame[:200]  # train/ reference data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 195  0.01381  80.0   0.46     0  0.422  7.875  32.0  5.6484    4  255
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 199  0.03150  95.0   1.47     0  0.403  6.975  15.3  7.6534    3  402
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 195     14.4  394.23   2.97  50.0
# 196     12.6  396.90   4.08  33.3
# 197     12.6  354.31   8.61  30.3
# 198     12.6  392.20   6.62  34.6
# 199     17.0  396.90   4.56  34.9
#
# [200 rows x 14 columns]

# %%
boston_frame[200:]  # test data
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 200  0.01778  95.0   1.47     0  0.4030  7.135  13.9  7.6534    3  402
# 201  0.03445  82.5   2.03     0  0.4150  6.162  38.4  6.2700    2  348
# 202  0.02177  82.5   2.03     0  0.4150  7.610  15.7  6.2700    2  348
# 203  0.03510  95.0   2.68     0  0.4161  7.853  33.2  5.1180    4  224
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# ..       ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.5730  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.5730  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.5730  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.5730  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.5730  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 200     17.0  384.30   4.45  32.9
# 201     14.7  393.77   7.43  24.1
# 202     14.7  395.38   3.11  42.3
# 203     14.7  392.78   3.81  48.5
# 204     14.7  390.55   2.88  50.0
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [306 rows x 14 columns]

# %% [markdown]
# # Data Drift Dashboard

# %%
boston_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 boston_data_drift_dashboard = Dashboard(tabs=[DataDriftTab()])
#
# NameError: name 'Dashboard' is not defined

# %%
boston_data_drift_dashboard.calculate(boston_frame[:200], boston_frame[200:])

# %%
boston_data_drift_dashboard.show()

# %%
boston_data_drift_dashboard.save("boston_data_drift_report.html")

# %%
boston_data_drift_profile = Profile(sections=[DataDriftProfileSection()])

# %%
boston_data_drift_profile.calculate(boston_frame[:200], boston_frame[200:])

# %%
boston_data_drift_profile.json()
